kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/data.yaml

# %%
model=YOLO("yolov10m.pt")

# ============================================================
# TRAIN MODEL
# ============================================================

results=model.train(

    data=YAML_PATH,

    epochs=50,

    imgsz=768,

    batch=16,

    device=0,

    workers=8,

    optimizer="AdamW",

    lr0=0.001,

    patience=20,

    pretrained=True,

    cache=True,

    # ========================================================
    # AUGMENTATION
    # ========================================================

    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,

    degrees=10,

    translate=0.1,

    scale=0.5,

    shear=2,

    perspective=0.0005,

    fliplr=0.5,

    mosaic=1.0,

    mixup=0.2,

    # ========================================================
    # OUTPUTS
    # ========================================================

    plots=True,

    verbose=True,

    project="ppe_training",

    name="yolov10_ppe"
)

print("\nTRAINING COMPLETED")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov10m.pt to 'yolov10m.pt': 100% ━━━━━━━━━━━━ 32.1MB 12.6MB/s 2.6s
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=768, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolov10m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov10_ppe, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=ppe_training, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/ppe_training/yolov10_ppe, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 40.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1     78720  ultralytics.nn.modules.block.SCDown          [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1    228672  ultralytics.nn.modules.block.SCDown          [384, 576, 3, 2]
#   8                  -1  2   1689984  ultralytics.nn.modules.block.C2fCIB          [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1   1253088  ultralytics.nn.modules.block.PSA             [576, 576]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  17                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2    831744  ultralytics.nn.modules.block.C2fCIB          [576, 384, 2, True]
#  20                  -1  1    152448  ultralytics.nn.modules.block.SCDown          [384, 384, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   1911168  ultralytics.nn.modules.block.C2fCIB          [960, 576, 2, True]
#  23        [16, 19, 22]  1   2284450  ultralytics.nn.modules.head.v10Detect        [3, [192, 384, 576]]
# YOLOv10m summary: 289 layers, 16,487,602 parameters, 16,487,586 gradients, 64.0 GFLOPs
#
# Transferred 787/799 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 150.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 19.5±10.6 MB/s, size: 77.5 KB)
# train: Scanning /kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/train/labels... 2991 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2991/2991 356.0it/s 8.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/train is not writable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (4.9GB RAM): 100% ━━━━━━━━━━━━ 2991/2991 434.1it/s 6.9s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.9±0.9 ms, read: 7.7±1.2 MB/s, size: 30.7 KB)
# val: Scanning /kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/valid/labels... 119 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 119/119 276.5it/s 0.4s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/roronazoromani/ppe-filtered/ppe_filtered/valid is not writable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.2GB RAM): 100% ━━━━━━━━━━━━ 119/119 145.7it/s 0.8s
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 129 weight(decay=0.0), 142 weight(decay=0.0005), 141 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/ppe_training/yolov10_ppe/labels.jpg...
# Image sizes 768 train, 768 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/ppe_training/yolov10_ppe
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50        12G      1.837      2.615      2.132        193        768: 100% ━━━━━━━━━━━━ 187/187 1.0it/s 3:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.7s/it 10.7s
#                    all        119        614      0.459      0.434      0.352     0.0902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      11.5G      1.864      2.257      2.128        190        768: 100% ━━━━━━━━━━━━ 187/187 1.1it/s 2:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.422      0.388       0.34      0.095
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      11.4G      1.812      2.233      2.096        162        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:42
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.324      0.411      0.267     0.0647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      11.5G      1.798      2.137      2.064        211        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.428      0.432      0.381     0.0993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      11.5G      1.766      2.029      2.029        136        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.544      0.462      0.465      0.116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      11.4G      1.742      1.953      2.011        192        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.574      0.567      0.561      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      11.6G       1.72      1.927      1.998        169        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.597      0.493      0.513      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      11.5G      1.705      1.901      1.986        120        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.547      0.584      0.548      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      11.5G      1.683      1.816      1.961        191        768: 100% ━━━━━━━━━━━━ 187/187 1.2it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614       0.61      0.589      0.608      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50
39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.6it/s 2.5s
#                    all        119        614      0.897      0.757      0.878      0.429
#
# 50 epochs completed in 2.298 hours.
# Optimizer stripped from /kaggle/working/runs/detect/ppe_training/yolov10_ppe/weights/last.pt, 33.5MB
# Optimizer stripped from /kaggle/working/runs/detect/ppe_training/yolov10_ppe/weights/best.pt, 33.5MB
#
# Validating /kaggle/working/runs/detect/ppe_training/yolov10_ppe/weights/best.pt...
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv10m summary (fused): 136 layers, 15,314,905 parameters, 0 gradients, 58.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2it/s 3.3s
#                    all        119        614      0.895      0.757      0.878      0.429
#                 helmet        117        232      0.914      0.822        0.9      0.422
#                 person        115        241      0.892      0.824      0.921      0.492
#                   vest         74        141       0.88      0.624      0.813      0.372
# Speed: 0.3ms preprocess, 19.0ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/ppe_training/yolov10_ppe
#
# TRAINING COMPLETED

# %%
best_model_path="/kaggle/working/ppe_training/yolov10_ppe/weights/best.pt"

print("\nBEST MODEL:")
print(best_model_path)

# ============================================================
# LOAD BEST MODEL
# ============================================================

best_model=YOLO(best_model_path)
# Out:
# BEST MODEL:
# /kaggle/working/ppe_training/yolov10_ppe/weights/best.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_24/3022330654.py in <cell line: 0>()
#       8 # ============================================================
#       9
# ---> 10 best_model=YOLO(best_model_path)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ---> 76             super().__init__(model=model, task=task, verbose=verbose)
#      77             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     142             self._new(model, task=task, verbose=verbose)
#     143         else:
# --> 144             self._load(model, task=task)
#     145
#     146         # Delete super().training for accessing self.model.training
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     281
#     282         if str(weights).rpartition(".")[-1] == "pt":
# --> 283             self.model, self.ckpt = load_checkpoint(weights)
#     284             self.task = self.model.task
#     285             self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in load_checkpoint(weight, device, inplace, fuse)
#    1535     if str(weight).lower().startswith(REMOTE_FILE_PREFIXES):
#    1536         weight = check_file(weight, download_dir=SETTINGS["weights_dir"])
# -> 1537     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1538     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1539     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in torch_safe_load(weight, safe_only)
#    1464
#    1465     try:
# -> 1466         ckpt = _load()
#    1467
#    1468     except RuntimeError as e:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in _load()
#    1461                 with open(file, "rb") as f:
#    1462                     return torch_load(f, pickle_module=safe_pickle)
# -> 1463             return torch_load(file, map_location="cpu")
#    1464
#    1465     try:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/patches.py in torch_load(*args, **kwargs)
#     179         kwargs["weights_only"] = False
#     180
# --> 181     return torch.load(*args, **kwargs)
#     182
#     183
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1498         pickle_load_args["encoding"] = "utf-8"
#    1499
# -> 1500     with _open_file_like(f, "rb") as opened_file:
#    1501         if _is_zipfile(opened_file):
#    1502             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     766 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     767     if _is_path(name_or_buffer):
# --> 768         return _open_file(name_or_buffer, mode)
#     769     else:
#     770         if "w" in mode:
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     747 class _open_file(_opener[IO[bytes]]):
#     748     def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749         super().__init__(open(name, mode))  # noqa: SIM115
#     750
#     751     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/ppe_training/yolov10_ppe/weights/best.pt'

# %%
metrics=best_model.val()

print("\n========== FINAL METRICS ==========")

print("mAP50:",metrics.box.map50)

print("mAP50-95:",metrics.box.map)

print("Precision:",metrics.box.mp)

print("Recall:",metrics.box.mr)

# %%
results_dir="/kaggle/working/ppe_training/yolov10_ppe"

graphs=[

    "results.png",

    "confusion_matrix.png",

    "confusion_matrix_normalized.png",

    "F1_curve.png",

    "P_curve.png",

    "R_curve.png",

    "PR_curve.png"
]

print("\nDISPLAYING TRAINING GRAPHS")

for graph in graphs:

    graph_path=os.path.join(results_dir,graph)

    if os.path.exists(graph_path):

        print(graph)

        display(Image(filename=graph_path))

# ============================================================
# RESULTS CSV
# ============================================================

results_csv=os.path.join(results_dir,"results.csv")

df=pd.read_csv(results_csv)

print("\nRESULTS CSV")

print(df.head())

# ============================================================
# LOSS CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["train/box_loss"],
    label="Train Box Loss"
)

plt.plot(
    df["epoch"],
    df["val/box_loss"],
    label="Validation Box Loss"
)

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.title("Box Loss Curve")

plt.legend()

plt.show()

# ============================================================
# mAP CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["metrics/mAP50(B)"],
    label="mAP50"
)

plt.plot(
    df["epoch"],
    df["metrics/mAP50-95(B)"],
    label="mAP50-95"
)

plt.xlabel("Epoch")

plt.ylabel("mAP")

plt.title("mAP Curve")

plt.legend()

plt.show()

# ============================================================
# PRECISION RECALL CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["metrics/precision(B)"],
    label="Precision"
)

plt.plot(
    df["epoch"],
    df["metrics/recall(B)"],
    label="Recall"
)

plt.xlabel("Epoch")

plt.ylabel("Score")

plt.title("Precision Recall Curve")

plt.legend()

plt.show()

# ============================================================
# TEST INFERENCE
# ============================================================

test_images=glob.glob(
    "/kaggle/working/ppe_filtered/test/images/*"
)

sample_images=random.sample(test_images,5)

print("\nRUNNING TEST INFERENCE")

for img_path in sample_images:

    best_model.predict(

        source=img_path,

        imgsz=768,

        conf=0.25,

        save=True
    )

# ============================================================
# DISPLAY PREDICTIONS
# ============================================================

pred_path="/kaggle/runs/detect/predict"

pred_images=glob.glob(f"{pred_path}/*.jpg")

print("\nSAMPLE PREDICTIONS")

for img in pred_images[:5]:

    display(Image(filename=img))

print("\nYOLOv10 TRAINING PIPELINE COMPLETED SUCCESSFULLY")
