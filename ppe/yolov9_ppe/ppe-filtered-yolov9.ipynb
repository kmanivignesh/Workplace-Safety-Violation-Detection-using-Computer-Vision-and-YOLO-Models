# %%
# !pip install ultralytics -q

import os
import glob
import random
import pandas as pd
import matplotlib.pyplot as plt

from ultralytics import YOLO
from IPython.display import display, Image
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.1 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
YAML_PATH="/kaggle/input/datasets/vigneshkothuri/ppe-filtered/ppe_filtered/data.yaml"

print(YAML_PATH)

# ============================================================
# LOAD YOLOv9 MODEL
# ============================================================

# OPTIONS:
# yolov9s.pt
# yolov9m.pt
# yolov9c.pt  <- recommended

model=YOLO("yolov9c.pt")
# Out:
# /kaggle/input/datasets/vigneshkothuri/ppe-filtered/ppe_filtered/data.yaml
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov9c.pt to 'yolov9c.pt': 100% ━━━━━━━━━━━━ 49.4MB 225.4MB/s 0.2s

# %%
results=model.train(

    data=YAML_PATH,

    epochs=100,

    imgsz=768,

    batch=16,

    device=0,

    workers=8,

    optimizer="AdamW",

    lr0=0.001,

    patience=10,

    pretrained=True,

    cache=True,

    # ========================================================
    # AUGMENTATION
    # ========================================================

    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,

    degrees=10,

    translate=0.1,

    scale=0.5,

    shear=2,

    perspective=0.0005,

    fliplr=0.5,

    mosaic=1.0,

    mixup=0.2,

    # ========================================================
    # OUTPUTS
    # ========================================================

    plots=True,

    verbose=True,

    project="ppe_training",

    name="yolov9_ppe"
)

print("\nTRAINING COMPLETED")
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/input/datasets/vigneshkothuri/ppe-filtered/ppe_filtered/data.yaml, degrees=10, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=768, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.2, mode=train, model=yolov9c.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolov9_ppe, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=10, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=ppe_training, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/ppe_training/yolov9_ppe, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=2, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 150.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    212864  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 256, 128, 64, 1]
#   3                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#   4                  -1  1    847616  ultralytics.nn.modules.block.RepNCSPELAN4    [256, 512, 256, 128, 1]
#   5                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   6                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   7                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#   8                  -1  1   2857472  ultralytics.nn.modules.block.RepNCSPELAN4    [512, 512, 512, 256, 1]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPELAN         [512, 512, 256]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    912640  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 256, 256, 128, 1]
#  16                  -1  1    164352  ultralytics.nn.modules.block.ADown           [256, 256]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1   2988544  ultralytics.nn.modules.block.RepNCSPELAN4    [768, 512, 512, 256, 1]
#  19                  -1  1    656384  ultralytics.nn.modules.block.ADown           [512, 512]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   3119616  ultralytics.nn.modules.block.RepNCSPELAN4    [1024, 512, 512, 256, 1]
#  22        [15, 18, 21]  1   5585113  ultralytics.nn.modules.head.Detect           [3, 16, None, [256, 512, 512]]
# YOLOv9c summary: 358 layers, 25,531,545 parameters, 25,531,529 gradients, 103.7 GFLOPs
#
# Transferred 931/937 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 259.6MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 14.4±4.1 MB/s, size: 77.5 KB)
# train: Scanning /kaggle/input/datasets/vigneshkothuri/ppe-filtered/ppe_filtered/train/labels... 2991 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2991/2991 287.3it/s 10.4s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/vigneshkothuri/ppe-filtered/ppe_filtered/train is not writable, cache not saved.
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (4.9GB RAM): 100% ━━━━━━━━━━━━ 2991/2991 451.1it/s 6.6s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read:
best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 78 epochs completed in 5.085 hours.
# Optimizer stripped from /kaggle/working/runs/detect/ppe_training/yolov9_ppe/weights/last.pt, 51.6MB
# Optimizer stripped from /kaggle/working/runs/detect/ppe_training/yolov9_ppe/weights/best.pt, 51.6MB
#
# Validating /kaggle/working/runs/detect/ppe_training/yolov9_ppe/weights/best.pt...
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv9c summary (fused): 156 layers, 25,321,561 parameters, 0 gradients, 102.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.1s/it 4.6s
#                    all        119        614      0.863      0.827      0.868      0.383
#                 helmet        117        232      0.868      0.853      0.868      0.377
#                 person        115        241      0.831      0.892      0.903      0.421
#                   vest         74        141      0.888      0.735      0.834       0.35
# Speed: 0.3ms preprocess, 25.2ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/ppe_training/yolov9_ppe
#
# TRAINING COMPLETED

# %%
best_model_path="/kaggle/working/ppe_training/yolov9_ppe/weights/best.pt"

print("\nBEST MODEL:")
print(best_model_path)

# ============================================================
# LOAD BEST MODEL
# ============================================================

best_model=YOLO(best_model_path)

# ============================================================
# VALIDATION
# ============================================================

metrics=best_model.val()

print("\n========== FINAL METRICS ==========")

print("mAP50:",metrics.box.map50)

print("mAP50-95:",metrics.box.map)

print("Precision:",metrics.box.mp)

print("Recall:",metrics.box.mr)

# ============================================================
# DISPLAY TRAINING GRAPHS
# ============================================================

results_dir="/kaggle/working/ppe_training/yolov9_ppe"

graphs=[

    "results.png",

    "confusion_matrix.png",

    "confusion_matrix_normalized.png",

    "F1_curve.png",

    "P_curve.png",

    "R_curve.png",

    "PR_curve.png"
]

print("\nDISPLAYING TRAINING GRAPHS")

for graph in graphs:

    graph_path=os.path.join(results_dir,graph)

    if os.path.exists(graph_path):

        print(graph)

        display(Image(filename=graph_path))

# ============================================================
# RESULTS CSV
# ============================================================

results_csv=os.path.join(results_dir,"results.csv")

df=pd.read_csv(results_csv)

print("\nRESULTS CSV")

print(df.head())

# ============================================================
# LOSS CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["train/box_loss"],
    label="Train Box Loss"
)

plt.plot(
    df["epoch"],
    df["val/box_loss"],
    label="Validation Box Loss"
)

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.title("Box Loss Curve")

plt.legend()

plt.show()

# ============================================================
# mAP CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["metrics/mAP50(B)"],
    label="mAP50"
)

plt.plot(
    df["epoch"],
    df["metrics/mAP50-95(B)"],
    label="mAP50-95"
)

plt.xlabel("Epoch")

plt.ylabel("mAP")

plt.title("mAP Curve")

plt.legend()

plt.show()

# ============================================================
# PRECISION RECALL CURVE
# ============================================================

plt.figure(figsize=(12,6))

plt.plot(
    df["epoch"],
    df["metrics/precision(B)"],
    label="Precision"
)

plt.plot(
    df["epoch"],
    df["metrics/recall(B)"],
    label="Recall"
)

plt.xlabel("Epoch")

plt.ylabel("Score")

plt.title("Precision Recall Curve")

plt.legend()

plt.show()

# ============================================================
# TEST INFERENCE
# ============================================================

test_images=glob.glob(
    "/kaggle/working/ppe_filtered/test/images/*"
)

sample_images=random.sample(test_images,5)

print("\nRUNNING TEST INFERENCE")

for img_path in sample_images:

    best_model.predict(

        source=img_path,

        imgsz=768,

        conf=0.25,

        save=True
    )

# ============================================================
# DISPLAY PREDICTIONS
# ============================================================

pred_path="/kaggle/runs/detect/predict"

pred_images=glob.glob(f"{pred_path}/*.jpg")

print("\nSAMPLE PREDICTIONS")

for img in pred_images[:5]:

    display(Image(filename=img))

print("\nYOLOv9 TRAINING PIPELINE COMPLETED SUCCESSFULLY")
# Out:
# BEST MODEL:
# /kaggle/working/ppe_training/yolov9_ppe/weights/best.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23/1468969823.py in <cell line: 0>()
#       8 # ============================================================
#       9
# ---> 10 best_model=YOLO(best_model_path)
#      11
#      12 # ============================================================
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      74         else:
#      75             # Continue with default YOLO initialization
# ---> 76             super().__init__(model=model, task=task, verbose=verbose)
#      77             if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      78                 from ultralytics import RTDETR
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     142             self._new(model, task=task, verbose=verbose)
#     143         else:
# --> 144             self._load(model, task=task)
#     145
#     146         # Delete super().training for accessing self.model.training
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     281
#     282         if str(weights).rpartition(".")[-1] == "pt":
# --> 283             self.model, self.ckpt = load_checkpoint(weights)
#     284             self.task = self.model.task
#     285             self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in load_checkpoint(weight, device, inplace, fuse)
#    1535     if str(weight).lower().startswith(REMOTE_FILE_PREFIXES):
#    1536         weight = check_file(weight, download_dir=SETTINGS["weights_dir"])
# -> 1537     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1538     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1539     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in torch_safe_load(weight, safe_only)
#    1464
#    1465     try:
# -> 1466         ckpt = _load()
#    1467
#    1468     except RuntimeError as e:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in _load()
#    1461                 with open(file, "rb") as f:
#    1462                     return torch_load(f, pickle_module=safe_pickle)
# -> 1463             return torch_load(file, map_location="cpu")
#    1464
#    1465     try:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/patches.py in torch_load(*args, **kwargs)
#     179         kwargs["weights_only"] = False
#     180
# --> 181     return torch.load(*args, **kwargs)
#     182
#     183
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1498         pickle_load_args["encoding"] = "utf-8"
#    1499
# -> 1500     with _open_file_like(f, "rb") as opened_file:
#    1501         if _is_zipfile(opened_file):
#    1502             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     766 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     767     if _is_path(name_or_buffer):
# --> 768         return _open_file(name_or_buffer, mode)
#     769     else:
#     770         if "w" in mode:
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     747 class _open_file(_opener[IO[bytes]]):
#     748     def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 749         super().__init__(open(name, mode))  # noqa: SIM115
#     750
#     751     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/ppe_training/yolov9_ppe/weights/best.pt'
